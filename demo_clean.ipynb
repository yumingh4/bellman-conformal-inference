# %%
"""
BCI Experiments - Clean Version
All helper functions are in separate files
"""

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import sys
sys.path.append('.')
sys.setrecursionlimit(10000)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("✓ Basic imports loaded")
# Out:
# ✓ Basic imports loaded

# %%
"""
Load BCI modules and apply experiment patch
"""
from utils import read_yaml
from experiment import ForecastingExperiment
from bci_utils import *
from visualize import gen_plot_data
from pid_external.pid_methods import quantile_integrator_log

# Apply the robust_run patch
from experiment_patch import apply_patch
apply_patch()

print("✓ All modules loaded and patched")
# Out:
# ✓ ForecastingExperiment.run() patched
# ✓ All modules loaded and patched

# %%
from bci_utils import (
    compute_metrics,           # ← Make sure this is here!
    compute_initial_miscov, 
    tune_lambda_init,
    estimate_lambda_max_from_warmup
)

# %%
"""
Returns (rtfc) - Calibrated Experiments
"""
from run_returns import run_returns_experiments

returns_results = run_returns_experiments()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 4
#       1 """
#       2 Returns (rtfc) - Calibrated Experiments
#       3 """
# ----> 4 from run_returns import run_returns_experiments
#       6 returns_results = run_returns_experiments()
#
# File ~/Documents/GitHub/bellman-conformal-inference/run_returns.py:24
#      21 import bci_utils
#      22 importlib.reload(bci_utils)
# ---> 24 from bci_utils import (
#      25     compute_metrics,
#      26     compute_initial_miscov,
#      27     tune_lambda_init,
#      28     estimate_lambda_max_from_warmup,
#      29     binary_search_bci_gamma  # *** ADDED: Missing import ***
#      30 )
#      32 from visualize import gen_plot_data
#      33 from pid_external.pid_methods import quantile_integrator_log
#
# ...

# %%
"""
Volatility (vlfc) - Calibrated Experiments
"""
from run_volatility import run_volatility_experiments

volatility_results = run_volatility_experiments()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 4
#       1 """
#       2 Volatility (vlfc) - Calibrated Experiments
#       3 """
# ----> 4 from run_volatility import run_volatility_experiments
#       6 volatility_results = run_volatility_experiments()
#
# File ~/Documents/GitHub/bellman-conformal-inference/run_volatility.py:45
#      43 from utils import read_yaml
#      44 from experiment import ForecastingExperiment
# ---> 45 from bci_utils import (
#      46     compute_metrics,
#      47     compute_initial_miscov,
#      48     tune_lambda_init,
#      49     estimate_lambda_max_from_warmup
#      50 )
#      51 from visualize import gen_plot_data
#      52 from pid_external.pid_methods import quantile_integrator_log
#
# ...

# %%
"""
Google Trends - Calibrated Experiments
"""
from run_trends import run_trends_experiments

trends_results = run_trends_experiments()
